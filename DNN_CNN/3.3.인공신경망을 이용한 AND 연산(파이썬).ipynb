# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import e

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
w = 2

# %%
b = 1

# %%
hypothesis = w * -3 + b

# %%
hypothesis
# Out:
# -5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
1/(1 + e ** -hypothesis)
# Out:
# 0.006692850924284857

# %%
hypothesis = w * -1.5 + b

# %%
hypothesis
# Out:
# -2.0

# %%
1 / (1 + e ** -hypothesis)
# Out:
# 0.11920292202211757

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.array([
          [0 , 0],
          [0 , 1],
          [1 , 0],
          [1 , 1]
] , dtype="float32")
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]], dtype=float32)

# %%
X = np.array([
          [0 , 0],
          [0 , 1],
          [1 , 0],
          [1 , 1]
          ] , dtype="float32")

# %%
X
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.array([
           [0],
           [0],
           [0],
          [1]
] , dtype="float32")
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %%
y = np.array([
              [0],
              [0],
              [0],
              [1]
             ] , dtype="float32")

# %%
y
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
w = np.array([
              [1],
              [2]
              ], dtype="float32")

# %%
w
# Out:
# array([[1.],
#        [2.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.dot(X , w)
# Out:
# array([[0.],
#        [2.],
#        [1.],
#        [3.]], dtype=float32)

# %%
b = np.array([3], dtype="float32")

# %%
b
# Out:
# array([3.], dtype=float32)

# %%
np.dot(X , w) + b
# Out:
# array([[3.],
#        [5.],
#        [4.],
#        [6.]], dtype=float32)

# %%
hypothesis = np.dot(X , w) + b

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hypothesis
# Out:
# array([[3.],
#        [5.],
#        [4.],
#        [6.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def sigmoid(h):
    return 1/(1 + np.exp(-h))

# %%
sigmoid( hypothesis )
# Out:
# array([[0.95257413],
#        [0.9933072 ],
#        [0.98201376],
#        [0.9975274 ]], dtype=float32)

# %%
hypothesis = sigmoid( hypothesis )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hypothesis
# Out:
# array([[0.95257413],
#        [0.9933072 ],
#        [0.98201376],
#        [0.9975274 ]], dtype=float32)

# %%
(hypothesis - y)
# Out:
# array([[ 0.95257413],
#        [ 0.9933072 ],
#        [ 0.98201376],
#        [-0.00247258]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]], dtype=float32)

# %%
X.T
# Out:
# array([[0., 0., 1., 1.],
#        [0., 1., 0., 1.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X.T[0]
# Out:
# array([0., 0., 1., 1.], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X.T[0].reshape(1, 4 )
# Out:
# array([[0., 0., 1., 1.]], dtype=float32)

# %%
x1 = X.T[0].reshape(1, 4 )

# %%
x1
# Out:
# array([[0., 0., 1., 1.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(hypothesis - y)
# Out:
# array([[ 0.95257413],
#        [ 0.9933072 ],
#        [ 0.98201376],
#        [-0.00247258]], dtype=float32)

# %%
np.dot(x1, (hypothesis - y))
# Out:
# array([[0.9795412]], dtype=float32)

# %%
np.sum( np.dot(x1, (hypothesis - y)) )
# Out:
# 0.9795412

# %%
1/4 * np.sum( np.dot(x1, (hypothesis - y)) )
# Out:
# 0.24488529562950134

# %%
w1_grad =  1/4 * np.sum( np.dot(x1, (hypothesis - y)) )

# %%
w1_grad
# Out:
# 0.24488529562950134

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X
# Out:
# array([[0., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 1.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X.T
# Out:
# array([[0., 0., 1., 1.],
#        [0., 1., 0., 1.]], dtype=float32)

# %%
X.T[1]
# Out:
# array([0., 1., 0., 1.], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X.T[1].reshape(1 , 4)
# Out:
# array([[0., 1., 0., 1.]], dtype=float32)

# %%
x2 = X.T[1].reshape(1 , 4)

# %%
x2
# Out:
# array([[0., 1., 0., 1.]], dtype=float32)

# %%
1/4 * np.dot (x2 , (hypothesis - y) )
# Out:
# array([[0.24770865]], dtype=float32)

# %%
1/4 * np.sum ( np.dot (x2 , (hypothesis - y) ) )
# Out:
# 0.24770864844322205

# %%
w2_grad = 1/4 * np.sum ( np.dot (x2 , (hypothesis - y) ) )

# %%
w2_grad
# Out:
# 0.24770864844322205

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = np.array([
              [1, 2, 3, 4]
    ], dtype="float32")

# %%
A
# Out:
# array([[1., 2., 3., 4.]], dtype=float32)

# %%
B = np.array([
              [5],
              [6],
              [7],
              [8]
    ], dtype="float32")

# %%
B
# Out:
# array([[5.],
#        [6.],
#        [7.],
#        [8.]], dtype=float32)

# %%
np.dot(A , B )
# Out:
# array([[70.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.dot( B , A)
# Out:
# array([[ 5., 10., 15., 20.],
#        [ 6., 12., 18., 24.],
#        [ 7., 14., 21., 28.],
#        [ 8., 16., 24., 32.]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(hypothesis - y)
# Out:
# array([[ 0.95257413],
#        [ 0.9933072 ],
#        [ 0.98201376],
#        [-0.00247258]], dtype=float32)

# %%
1/4 * np.sum( (hypothesis - y) )
# Out:
# 0.731355607509613

# %%
b_grad =1/4 * np.sum( (hypothesis - y) )

# %%
b_grad
# Out:
# 0.731355607509613

# %%
w
# Out:
# array([[1.],
#        [2.]], dtype=float32)

# %%
b
# Out:
# array([3.], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
w[0] = w[0] - 0.1 * w1_grad

# %%
w[1] = w[1] - 0.1 * w2_grad

# %%
w
# Out:
# array([[0.9755115],
#        [1.9752291]], dtype=float32)

# %%
b = b - 0.1 * b_grad

# %%
b
# Out:
# array([2.9268644], dtype=float32)

# %%
hypothesis = sigmoid(np.dot(X, w) + b)

# %%
hypothesis
# Out:
# array([[0.94915855],
#        [0.9926238 ],
#        [0.9802059 ],
#        [0.9972063 ]], dtype=float32)

# %%
cost = -1/4*(y * np.log(hypothesis)) + (1-y) * np.log(1-hypothesis)

# %%
cost
# Out:
# array([[-2.9790432e+00],
#        [-4.9094977e+00],
#        [-3.9223711e+00],
#        [ 6.9940975e-04]], dtype=float32)
