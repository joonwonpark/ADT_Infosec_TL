# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
! git clone https://github.com/metal3d/keras-video-generators.git
# Out:
# Cloning into 'keras-video-generators'...
# remote: Enumerating objects: 614, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 614 (delta 47), reused 75 (delta 35), pack-reused 514
# Receiving objects: 100% (614/614), 7.77 MiB | 30.58 MiB/s, done.
# Resolving deltas: 100% (279/279), done.

# %%
import os
# 다운로드한 폴더로 이동
os.chdir("/content/keras-video-generators/")

# %%
# git 컴파일
! python setup.py build
# Out:
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'licence_file'
#   warnings.warn(msg)
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/keras_video
# copying src/keras_video/__init__.py -> build/lib/keras_video
# copying src/keras_video/utils.py -> build/lib/keras_video
# copying src/keras_video/sliding.py -> build/lib/keras_video
# copying src/keras_video/generator.py -> build/lib/keras_video
# copying src/keras_video/flow.py -> build/lib/keras_video

# %%
# 폴더 생성
! mkdir /content/keras_video
# git 파일 복사 /content/keras_video
! cp /content/keras-video-generators/build/lib/keras_video/*.*  /content/keras_video

# %%
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras_video import VideoFrameGenerator
import sklearn
from tensorflow.keras.models import Sequential
from keras.applications import vgg16, vgg19
from tensorflow.keras.layers import TimeDistributed, GRU, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

import keras_video.utils
from tensorflow_docs.vis import embed
import imageio

from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X_train = np.load('/content/drive/MyDrive/4차 모듈 프로젝트_4조/data/X_train(5).npy')
y_train = np.load('/content/drive/MyDrive/4차 모듈 프로젝트_4조/data/y_train(5).npy')

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (356, 20, 224, 224, 3)
# (356, 3)

# %% [markdown]
# ### 비디오 증강

# %%
# 데이터 경로
data_path = "/content/drive/MyDrive/cloud_ai/16.모듈프로젝트04/workspace/"

# %%
# 학습 데이터의 파일명과 종류가 저장된 train.csv 를 읽음
train_df = pd.read_csv(data_path + "train.csv")

# %%
# 비디오의 종류가 저장된 tag 컬럼을 label 컬럼에 대입
train_df["label"] = train_df["tag"]

# %%
train_df
# Out:
#                     video_name          tag        label
# 0    v_CricketShot_g08_c01.avi  CricketShot  CricketShot
# 1    v_CricketShot_g08_c02.avi  CricketShot  CricketShot
# 2    v_CricketShot_g08_c03.avi  CricketShot  CricketShot
# 3    v_CricketShot_g08_c04.avi  CricketShot  CricketShot
# 4    v_CricketShot_g08_c05.avi  CricketShot  CricketShot
# ..                         ...          ...          ...
# 351  v_TennisSwing_g25_c02.avi  TennisSwing  TennisSwing
# 352  v_TennisSwing_g25_c03.avi  TennisSwing  TennisSwing
# 353  v_TennisSwing_g25_c04.avi  TennisSwing  TennisSwing
# 354  v_TennisSwing_g25_c05.avi  TennisSwing  TennisSwing
# 355  v_TennisSwing_g25_c06.avi  TennisSwing  TennisSwing
#
# [356 rows x 3 columns]

# %%
# sklearn.utils.shuffle(train_df) : train_df에 저장된 행을 섞음
train_df=sklearn.utils.shuffle(train_df)

# %%
# train_df에 저장된 줄이 섞였음
train_df
# Out:
#                     video_name          tag        label
# 290  v_TennisSwing_g15_c04.avi  TennisSwing  TennisSwing
# 230        v_Punch_g24_c06.avi        Punch        Punch
# 6    v_CricketShot_g08_c07.avi  CricketShot  CricketShot
# 66   v_CricketShot_g17_c04.avi  CricketShot  CricketShot
# 262  v_TennisSwing_g11_c04.avi  TennisSwing  TennisSwing
# ..                         ...          ...          ...
# 69   v_CricketShot_g18_c01.avi  CricketShot  CricketShot
# 340  v_TennisSwing_g23_c03.avi  TennisSwing  TennisSwing
# 167        v_Punch_g15_c02.avi        Punch        Punch
# 17   v_CricketShot_g10_c04.avi  CricketShot  CricketShot
# 344  v_TennisSwing_g24_c01.avi  TennisSwing  TennisSwing
#
# [356 rows x 3 columns]

# %%
# tag에 저장된 라벨을 리턴
classes = train_df["tag"].unique().tolist()

# %%
# 라벨 정렬
classes.sort()

# %%
# 라벨 데이터 조회
classes
# Out:
# ['CricketShot', 'Punch', 'TennisSwing']

# %%
# train, validation data 분할
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# %%
# 이미지 사이즈
SIZE = (224, 224)
CHANNELS = 3

# %%
# 비디오 프레임의 이미지를 변형 할 객체 변형할 객체
train_image_data_gen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=30, # 이미지 회전 각도 최대 30도
	zoom_range=0.15, # 이미지 확대 비율 
	width_shift_range=0.2, # 이미지 가로 이동 비율
	height_shift_range=0.2, # 이미지 세로 이동 비율
	shear_range=0.15, # 이미지 기울기 비율
	horizontal_flip=True,# 이미지 좌우 반전을 가능하도록 설정
	fill_mode="nearest", # 이미지를 회전 이동시 빈공간을 채우는 방식
)

# %%
# 비디오 파일의 클래스 v_다음이 클래스임
glob_pattern=data_path+'train/v_{classname}_*.avi'

# %%
# 비디오 프레임 20개 생성할 객체
train_video_generator = VideoFrameGenerator(
    classes=classes, # 분류할 클래스 설정 : ['CricketShot', 'Punch', 'TennisSwing']
    glob_pattern=glob_pattern, # 파일명에서 클래스 정보를 따옴
    nb_frames=20,              # 시퀀스의 프레임의 수 
    split=.33,                 # 검증용 파일로 나눌 분할 비율 
    shuffle=True,              # 섞을 것 인지 
    batch_size=2,              # 배치사이즈는 2로 설정 한 배치의 시퀀스 수
    target_shape=SIZE,         # 요소 2에서 만든 (224,224)
    nb_channel=CHANNELS,       # 요소 2에서 만든 3  3이니까 RGB 채널 
    transformation=train_image_data_gen, # 요소 3에서 만든 비디오 프레임의 변형 
    use_frame_cache=True       # 프레임 캐시를 사용할지 여부 / 사용을 위해 다량의 메모리 필요 
    )
# Out:
# Total data: 3 classes for 356 files for train

# %%
# 비디오 프레임 샘플 데이터 조회 (배치사이즈 만큼)
keras_video.utils.show_sample(train_video_generator)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential()

# %%
model.add(
    TimeDistributed(
        tf.keras.applications.VGG16(
        weights='imagenet'
        ,include_top=False
        ,input_shape=(224,224,3)
        )
        ,input_shape=(20,224,224,3)
    )
)

model.add(TimeDistributed(Dropout(0.5)))

model.add(TimeDistributed(Flatten()))
model.add(GRU(256, dropout=0.5))


model.add(Dense(128, activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(3, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 20, 7, 7, 512)     14714688
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 7, 7, 512)     0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 25088)         0
# _________________________________________________________________
# gru (GRU)                    (None, 256)               19465728
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 34,213,699
# Trainable params: 34,213,699
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5)
                ,loss='categorical_crossentropy'
                ,metrics=['accuracy']
            )

# %% [markdown]
# gru_model = tf.keras.layers.GRU(
#     units=(X_train/255).any(),
#     activation="tanh",
#     recurrent_activation="sigmoid",
#     use_bias=True,
#     kernel_initializer="glorot_uniform",
#     recurrent_initializer="orthogonal",
#     bias_initializer="zeros",
#     kernel_regularizer=None,
#     recurrent_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     recurrent_constraint=None,
#     bias_constraint=None,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
#     unroll=False,
#     time_major=False,
#     reset_after=True # True
# )

# %%
# checkpoint 만들기
checkpoint_path = '/content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt'

checkpoint = ModelCheckpoint(
    filepath=checkpoint_path
    ,save_weights_only=True
    ,save_best_only=True
    ,monitor='val_loss'
    ,verbose=1
)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 이미지 학습
model.fit(
	train_video_generator
#	,X_train, y_train
	,batch_size=1
	,epochs=50 # lr : 1e-5
	,validation_data=(X_val, y_val)
	,callbacks=[checkpoint]
	,verbose=1
)
# Out:
# Epoch 1/50
# 178/178 [==============================] - 238s 1s/step - loss: 1.3549 - accuracy: 0.3539 - val_loss: 0.8723 - val_accuracy: 0.6742
#
# Epoch 00001: val_loss improved from inf to 0.87226, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 2/50
# 178/178 [==============================] - 87s 486ms/step - loss: 1.1401 - accuracy: 0.4663 - val_loss: 0.7212 - val_accuracy: 0.7865
#
# Epoch 00002: val_loss improved from 0.87226 to 0.72117, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 3/50
# 178/178 [==============================] - 87s 485ms/step - loss: 0.9349 - accuracy: 0.5478 - val_loss: 0.4581 - val_accuracy: 0.8876
#
# Epoch 00003: val_loss improved from 0.72117 to 0.45808, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 4/50
# 178/178 [==============================] - 86s 484ms/step - loss: 0.7179 - accuracy: 0.6685 - val_loss: 0.3182 - val_accuracy: 0.9326
#
# Epoch 00004: val_loss improved from 0.45808 to 0.31816, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 5/50
# 178/178 [==============================] - 87s 488ms/step - loss: 0.6319 - accuracy: 0.7051 - val_loss: 0.3011 - val_accuracy: 0.9775
#
# Epoch 00005: val_loss improved from 0.31816 to 0.30112, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 6/50
# 178/178 [==============================] - 87s 489ms/step - loss: 0.5431 - accuracy: 0.7528 - val_loss: 0.1713 - val_accuracy: 0.9775
#
# Epoch 00006: val_loss improved from 0.30112 to 0.17132, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 7/50
# 178/178 [==============================] - 87s 487ms/step - loss: 0.4988 - accuracy: 0.7753 - val_loss: 0.0878 - val_accuracy: 0.9775
#
# Epoch 00007: val_loss improved from 0.17132 to 0.08783, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 8/50
# 178/178 [==============================] - 87s 485ms/step - loss: 0.4154 - accuracy: 0.8680 - val_loss: 0.1140 - val_accuracy: 0.9663
#
# Epoch 00008: val_loss did not improve from 0.08783
# Epoch 9/50
# 178/178 [==============================] - 86s 479ms/step - loss: 0.2939 - accuracy: 0.8961 - val_loss: 0.0583 - val_accuracy: 0.9775
#
# Epoch 00009: val_loss improved from 0.08783 to 0.05828, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 10/50
# 178/178 [==============================] - 86s 481ms/step - loss: 0.2360 - accuracy: 0.9185 - val_loss: 0.0145 - val_accuracy: 1.0000
#
# Epoch 00010: val_loss improved from 0.05828 to 0.01455, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 11/50
# 178/178 [==============================] - 86s 485ms/step - loss: 0.2263 - accuracy: 0.9213 - val_loss: 0.0157 - val_accuracy: 1.0000
#
# Epoch 00011: val_loss did not improve from 0.01455
# Epoch 12/50
# 178/178 [==============================] - 86s 483ms/step - loss: 0.1520 - accuracy: 0.9522 - val_loss: 0.0064 - val_accuracy: 1.0000
#
# Epoch 00012: val_loss improved from 0.01455 to 0.00639, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 13/50
# 178/178 [==============================] - 87s 485ms/step - loss: 0.1275 - accuracy: 0.9607 - val_loss: 0.0032 - val_accuracy: 1.0000
#
# Epoch 00013: val_loss improved from 0.00639 to 0.00323, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 14/50
# 178/178 [==============================] - 87s 487ms/step - loss: 0.1840 - accuracy: 0.9635 - val_loss: 0.0490 - val_accuracy: 0.9775
#
# Epoch 00014: val_loss did not improve from 0.00323
# Epoch 15/50
# 178/178 [==============================] - 87s 485ms/step - loss: 0.0840 - accuracy: 0.9691 - val_loss: 0.0266 - val_accuracy: 0.9775
#
# Epoch 00015: val_loss did not improve from 0.00323
# Epoch 16/50
# 178/178 [==============================] - 86s 484ms/step - loss: 0.0791 - accuracy: 0.9747 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00016: val_loss improved from 0.00323 to 0.00121, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 17/50
# 178/178 [==============================] - 87s 490ms/step - loss: 0.0704 - accuracy: 0.9831 - val_loss: 0.0044 - val_accuracy: 1.0000
#
# Epoch 00017: val_loss did not improve from 0.00121
# Epoch 18/50
# 178/178 [==============================] - 86s 484ms/step - loss: 0.0771 - accuracy: 0.9775 - val_loss: 0.0074 - val_accuracy: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.00121
# Epoch 19/50
# 178/178 [==============================] - 86s 483ms/step - loss: 0.1628 - accuracy: 0.9635 - val_loss: 0.0130 - val_accuracy: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.00121
# Epoch 20/50
# 178/178 [==============================] - 85s 476ms/step - loss: 0.0813 - accuracy: 0.9860 - val_loss: 6.5110e-04 - val_accuracy: 1.0000
#
# Epoch 00020: val_loss improved from 0.00121 to 0.00065, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 21/50
# 178/178 [==============================] - 86s 484ms/step - loss: 0.0439 - accuracy: 0.9944 - val_loss: 1.3434e-04 - val_accuracy: 1.0000
#
# Epoch 00021: val_loss improved from 0.00065 to 0.00013, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 22/50
# 178/178 [==============================] - 85s 477ms/step - loss: 0.0468 - accuracy: 0.9972 - val_loss: 1.4741e-04 - val_accuracy: 1.0000
#
# Epoch 00022: val_loss did not improve from 0.00013
# Epoch 23/50
# 178/178 [==============================] - 85s 477ms/step - loss: 0.0886 - accuracy: 0.9831 - val_loss: 3.5481e-04 - val_accuracy: 1.0000
#
# Epoch 00023: val_loss did not improve from 0.00013
# Epoch 24/50
# 178/178 [==============================] - 85s 477ms/step - loss: 0.0368 - accuracy: 0.9916 - val_loss: 1.0482e-04 - val_accuracy: 1.0000
#
# Epoch 00024: val_loss improved from 0.00013 to 0.00010, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 25/50
# 178/178 [==============================] - 85s 478ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 8.7048e-05 - val_accuracy: 1.0000
#
# Epoch 00025: val_loss improved from 0.00010 to 0.00009, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 26/50
# 178/178 [==============================] - 87s 486ms/step - loss: 0.0235 - accuracy: 0.9944 - val_loss: 7.3486e-05 - val_accuracy: 1.0000
#
# Epoch 00026: val_loss improved from 0.00009 to 0.00007, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 27/50
# 178/178 [==============================] - 86s 481ms/step - loss: 0.0200 - accuracy: 0.9972 - val_loss: 7.3143e-05 - val_accuracy: 1.0000
#
# Epoch 00027: val_loss improved from 0.00007 to 0.00007, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 28/50
# 178/178 [==============================] - 86s 481ms/step - loss: 0.1373 - accuracy: 0.9579 - val_loss: 0.0025 - val_accuracy: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.00007
# Epoch 29/50
# 178/178 [==============================] - 85s 475ms/step - loss: 0.0271 - accuracy: 0.9944 - val_loss: 0.0022 - val_accuracy: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.00007
# Epoch 30/50
# 178/178 [==============================] - 85s 478ms/step - loss: 0.0241 - accuracy: 0.9944 - val_loss: 1.2190e-04 - val_accuracy: 1.0000
#
# Epoch 00030: val_loss did not improve from 0.00007
# Epoch 31/50
# 178/178 [==============================] - 85s 476ms/step - loss: 0.0327 - accuracy: 0.9916 - val_loss: 5.4821e-05 - val_accuracy: 1.0000
#
# Epoch 00031: val_loss improved from 0.00007 to 0.00005, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 32/50
# 178/178 [==============================] - 86s 481ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 3.6922e-05 - val_accuracy: 1.0000
#
# Epoch 00032: val_loss improved from 0.00005 to 0.00004, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 33/50
# 178/178 [==============================] - 87s 487ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 3.3938e-05 - val_accuracy: 1.0000
#
# Epoch 00033: val_loss improved from 0.00004 to 0.00003, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 34/50
# 178/178 [==============================] - 87s 487ms/step - loss: 0.0557 - accuracy: 0.9775 - val_loss: 6.3954e-04 - val_accuracy: 1.0000
#
# Epoch 00034: val_loss did not improve from 0.00003
# Epoch 35/50
# 178/178 [==============================] - 86s 479ms/step - loss: 0.0366 - accuracy: 0.9916 - val_loss: 1.2840e-04 - val_accuracy: 1.0000
#
# Epoch 00035: val_loss did not improve from 0.00003
# Epoch 36/50
# 178/178 [==============================] - 86s 480ms/step - loss: 0.0149 - accuracy: 0.9972 - val_loss: 0.0011 - val_accuracy: 1.0000
#
# Epoch 00036: val_loss did not improve from 0.00003
# Epoch 37/50
# 178/178 [==============================] - 86s 482ms/step - loss: 0.0843 - accuracy: 0.9663 - val_loss: 7.8216e-05 - val_accuracy: 1.0000
#
# Epoch 00037: val_loss did not improve from 0.00003
# Epoch 38/50
# 178/178 [==============================] - 86s 480ms/step - loss: 0.0284 - accuracy: 0.9944 - val_loss: 5.4543e-05 - val_accuracy: 1.0000
#
# Epoch 00038: val_loss did not improve from 0.00003
# Epoch 39/50
# 178/178 [==============================] - 86s 480ms/step - loss: 0.0475 - accuracy: 0.9860 - val_loss: 5.7215e-05 - val_accuracy: 1.0000
#
# Epoch 00039: val_loss did not improve from 0.00003
# Epoch 40/50
# 178/178 [==============================] - 86s 482ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 2.3575e-05 - val_accuracy: 1.0000
#
# Epoch 00040: val_loss improved from 0.00003 to 0.00002, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 41/50
# 178/178 [==============================] - 87s 486ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 2.0080e-05 - val_accuracy: 1.0000
#
# Epoch 00041: val_loss improved from 0.00002 to 0.00002, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 42/50
# 178/178 [==============================] - 87s 485ms/step - loss: 0.0120 - accuracy: 0.9972 - val_loss: 1.8643e-05 - val_accuracy: 1.0000
#
# Epoch 00042: val_loss improved from 0.00002 to 0.00002, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 43/50
# 178/178 [==============================] - 87s 486ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.8616e-05 - val_accuracy: 1.0000
#
# Epoch 00043: val_loss improved from 0.00002 to 0.00002, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 44/50
# 178/178 [==============================] - 87s 490ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.5165e-05 - val_accuracy: 1.0000
#
# Epoch 00044: val_loss improved from 0.00002 to 0.00002, saving model to /content/drive/MyDrive/4차 모듈 프로젝트_4조/model/tmp_checkpoint.ckpt
# Epoch 45/50
# 178/178 [==============================] - 87s 485ms/step - loss: 0.0323 - accuracy: 0.9888 - val_loss: 0.0018 - val_accuracy: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.00002
# Epoch 46/50
# 178/178 [==============================] - 86s 481ms/step - loss: 0.0101 - accuracy: 0.9944 - val_loss: 1.9437e-05 - val_accuracy: 1.0000
#
# Epoch 00046: val_loss did not improve from 0.00002
# Epoch 47/50
# 178/178 [==============================] - 85s 478ms/step - loss: 0.0327 - accuracy: 0.9916 - val_loss: 6.8554e-05 - val_accuracy: 1.0000
#
# Epoch 00047: val_loss did not improve from 0.00002
# Epoch 48/50
# 178/178 [==============================] - 86s 484ms/step - loss: 0.1923 - accuracy: 0.9494 - val_loss: 1.4718e-04 - val_accuracy: 1.0000
#
# Epoch 00048: val_loss did not improve from 0.00002
# Epoch 49/50
# 178/178 [==============================] - 86s 480ms/step - loss: 0.0349 - accuracy: 0.9916 - val_loss: 0.0017 - val_accuracy: 1.0000
#
# Epoch 00049: val_loss did not improve from 0.00002
# Epoch 50/50
# 178/178 [==============================] - 86s 480ms/step - loss: 0.0292 - accuracy: 0.9944 - val_loss: 2.1187e-05 - val_accuracy: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.00002

# %%
model.load_weights(checkpoint_path)

# %%
model.save('/content/drive/MyDrive/4차 모듈 프로젝트_4조/model/VGG-16+GRU_cv,vg,cb(lr=1e5,ep=50).h5')

# %% [markdown]
# ### test

# %%
model = keras.models.load_model('/content/drive/MyDrive/4차 모듈 프로젝트_4조/model/VGG-16+GRU_cv,vg,cb(lr=1e5,ep=50).h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 20, 7, 7, 512)     14714688
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 7, 7, 512)     0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 25088)         0
# _________________________________________________________________
# gru (GRU)                    (None, 256)               19465728
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 34,213,699
# Trainable params: 34,213,699
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 비디오 증강

# %%
X_test = np.load('/content/drive/MyDrive/4차 모듈 프로젝트_4조/data/X_test(5).npy')
y_test = np.load('/content/drive/MyDrive/4차 모듈 프로젝트_4조/data/y_test(5).npy')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 이미지 테스트
model.evaluate(
    X_test, y_test
    , batch_size = 8 # epochs=50
    # loss: 0.0292 - accuracy: 0.9944 - val_loss: 2.1187e-05 - val_accuracy: 1.0000
)
# Out:
# 18/18 [==============================] - 32s 390ms/step - loss: 0.1111 - accuracy: 0.9562
# [0.11110024154186249, 0.956204354763031]

# %% [markdown]
# ### 임의의 영상으로 테스트 확인

# %%
shuffled_test_df = pd.read_csv('/content/drive/MyDrive/4차 모듈 프로젝트_4조/data/shuffled_test.csv')
shuffled_test_df
# Out:
#      Unnamed: 0                 video_name          tag  label
# 0            29  v_CricketShot_g05_c02.avi  CricketShot      0
# 1            92  v_TennisSwing_g01_c05.avi  TennisSwing      2
# 2           130  v_TennisSwing_g07_c01.avi  TennisSwing      2
# 3           101  v_TennisSwing_g02_c07.avi  TennisSwing      2
# 4            69        v_Punch_g05_c03.avi        Punch      1
# ..          ...                        ...          ...    ...
# 132         125  v_TennisSwing_g06_c03.avi  TennisSwing      2
# 133          28  v_CricketShot_g05_c01.avi  CricketShot      0
# 134          66        v_Punch_g04_c05.avi        Punch      1
# 135           2  v_CricketShot_g01_c03.avi  CricketShot      0
# 136           5  v_CricketShot_g01_c06.avi  CricketShot      0
#
# [137 rows x 4 columns]

# %%
# sklearn.utils.shuffle(train_df) : train_df에 저장된 행을 섞음
shuffled_test_df=sklearn.utils.shuffle(shuffled_test_df)

# %%
# tag에 저장된 라벨을 리턴
classes = shuffled_test_df["tag"].unique().tolist()

# %%
# 라벨 정렬
classes.sort()

# %%
# 라벨 데이터 조회
classes
# Out:
# ['CricketShot', 'Punch', 'TennisSwing']

# %%
classes
# Out:
# ['CricketShot', 'Punch', 'TennisSwing']

# %%
# 0번째 비디오 프레임 이미지
plt.imshow(X_test[0][0])

# %%
# 0번째 비디오 프레임 이미지
frame = X_test[90:91]
# 비디오 프레임 이미지의 종류 예측
predict01 = model.predict(frame)
print("predict01 = ", predict01)
# 최고값이 있는 인덱스 조회
predict02 = np.argmax(predict01, axis=1)
print("predict02 = ", predict02)
# 이미지의 종류 조회
text_predict = classes[predict02[0]]
print("text_predict=", text_predict)
# Out:
# predict01 =  [[4.0929754e-05 4.1672504e-07 9.9995863e-01]]
# predict02 =  [2]
# text_predict= TennisSwing

# %%
# 0번째 비디오 프레임 이미지 image에 대입
image = frame[0][0].copy()
plt.imshow(image)

# %%
# 이미지의 종류
str = "Activity :{}".format(text_predict)
# str을 출력할 이미지 좌표
org=(0,20) 
# 이미지 폰트
font=cv2.FONT_HERSHEY_PLAIN
# image에 str을 출력
cv2.putText(image,str,org,font, 1 ,(255,0, 0) , False)
# Out:
# array([[[0.21960784, 0.25490198, 0.30588236],
#         [0.3137255 , 0.3529412 , 0.4       ],
#         [0.2784314 , 0.3529412 , 0.38431373],
#         ...,
#         [0.95686275, 0.99607843, 0.972549  ],
#         [0.95686275, 0.99607843, 0.972549  ],
#         [0.95686275, 0.99607843, 0.972549  ]],
#
#        [[0.10980392, 0.14901961, 0.2       ],
#         [0.5764706 , 0.62352943, 0.6666667 ],
#         [0.67058825, 0.74509805, 0.7764706 ],
#         ...,
#         [0.95686275, 0.99607843, 0.972549  ],
#         [0.95686275, 0.99607843, 0.972549  ],
#         [0.95686275, 0.99607843, 0.972549  ]],
#
#        [[0.20784314, 0.3019608 , 0.31764707],
#         [0.6117647 , 0.7058824 , 0.72156864],
#         [0.5568628 , 0.6431373 , 0.6509804 ],
#         ...,
#         [0.95686275, 0.99607843, 0.972549  ],
#         [0.95686275, 0.99607843, 0.972549  ],
#         [0.95686275, 0.99607843, 0.972549  ]],
#
#        ...,
#
#        [[0.25490198, 0.32941177, 0.28627452],
#         [0.25490198, 0.32941177, 0.28627452],
#         [0.25490198, 0.32941177, 0.28627452],
#         ...,
#         [0.18431373, 0.2509804 , 0.26666668],
#         [0.17254902, 0.23921569, 0.25490198],
#         [0.16862746, 0.23529412, 0.2509804 ]],
#
#        [[0.25490198, 0.32941177, 0.28627452],
#         [0.25490198, 0.32941177, 0.28627452],
#         [0.25490198, 0.32941177, 0.28627452],
#         ...,
#         [0.26666668, 0.3137255 , 0.3372549 ],
#         [0.27058825, 0.31764707, 0.34117648],
#         [0.26666668, 0.31764707, 0.34117648]],
#
#        [[0.25490198, 0.32941177, 0.28627452],
#         [0.25490198, 0.32941177, 0.28627452],
#         [0.25490198, 0.32941177, 0.28627452],
#         ...,
#         [0.25882354, 0.30588236, 0.32941177],
#         [0.25882354, 0.30588236, 0.32941177],
#         [0.25882354, 0.30588236, 0.32941177]]], dtype=float32)

# %%
# image에 str (영상 종류 예측값 ) 출력
plt.imshow(image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 0으로 초기화된 [20,224,224,3 ] 배열 생성
images = np.zeros(shape=(20,224,224,3))
# X_test의 0번째 비디오
frame = X_test[0:1]
# 비디오  종류 예측
predict01 = model.predict(frame)
# 최고값이 있는 인덱스 조회
predict02 = np.argmax(predict01, axis=1)
# 이미지의 종류 조회
text_predict = classes[predict02[0]]
# 이미지의 종류
str = "Activity :{}".format(text_predict)
print("str = ", str)
for i in range(20):
    #frame 복사
    image = frame[0][i].copy()
    # str을 출력할 이미지 좌표
    org=(0,20) 
    # 이미지 폰트
    font=cv2.FONT_HERSHEY_PLAIN
    # image에 str을  출력
    cv2.putText(image,str,org,font, 1 ,(255,0, 0) , False)
    # images에 image 추가
    images[i] = image * 255
# Out:
# str =  Activity :CricketShot

# %%
# images를 정수로 변환
converted_images = images.astype(np.uint8)
# converted_images 를 animation.gif로 변환
imageio.mimsave("animation.gif", converted_images, fps=20)
# animation.gif 를 출력
embed.embed_file("animation.gif")
# Out:
# <img src="data:image/gif;base64,..."/>
