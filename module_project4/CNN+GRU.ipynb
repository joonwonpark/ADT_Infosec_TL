# %%
# !pip install -q git+https://github.com/tensorflow/docs

# %%
! git clone https://github.com/metal3d/keras-video-generators.git
# Out:
# fatal: destination path 'keras-video-generators' already exists and is not an empty directory.

# %%
# 다운로드한 폴더로 이동
import os
os.chdir("/content/keras-video-generators/")

# %%
# git 컴파일
! python setup.py build
# Out:
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'licence_file'
#   warnings.warn(msg)
# running build
# running build_py

# %%
# 폴더 생성
! mkdir /content/keras_video
# git 파일 복사 /content/keras_video
! cp /content/keras-video-generators/build/lib/keras_video/*.*  /content/keras_video
# Out:
# mkdir: cannot create directory ‘/content/keras_video’: File exists

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np

import cv2
import pandas as pd
from tensorflow.keras.utils import to_categorical
from keras_video import VideoFrameGenerator

import sklearn
import keras_video.utils
from tensorflow_docs.vis import embed
import imageio
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import TimeDistributed, Dropout, GRU
from tensorflow.keras.optimizers import Adam

# %%
data_path = '/content/drive/MyDrive'

# %%
X_train = np.load(data_path + '/data/X_train_wide(5).npy')

# %%
y_train = np.load(data_path + '/data/y_train_wide(5).npy')

# %%
model = Sequential()

model.add(
            TimeDistributed(
                            Conv2D(32, kernel_size=(3,3) , activation="relu", padding="SAME")   
                        
             , input_shape=(20, 224, 224, 3)  
             )     
          )

model.add(TimeDistributed(MaxPooling2D( pool_size=2, padding="SAME", strides=2) ))
model.add(TimeDistributed(Conv2D(64, kernel_size=(3,3), activation="relu", padding="SAME")))
model.add(TimeDistributed(MaxPooling2D(pool_size=2, padding="SAME", strides=2)))
model.add(TimeDistributed(Conv2D(128, kernel_size=(3,3), padding="SAME", activation="relu")))
model.add(TimeDistributed(MaxPooling2D(pool_size=2, padding="SAME", strides=2)))
model.add(TimeDistributed(Flatten()))
model.add(Dropout(0.5))

model.add(TimeDistributed(Flatten()))
model.add(GRU(256, dropout=0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#생성된 모델 정보 출력
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 20, 224, 224, 32)  896
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 112, 112, 32)  0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 112, 112, 64)  18496
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 20, 56, 56, 64)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 20, 56, 56, 128)   73856
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 20, 28, 28, 128)   0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 20, 100352)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 20, 100352)        0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 20, 100352)        0
# _________________________________________________________________
# gru (GRU)                    (None, 256)               77268480
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 77,395,011
# Trainable params: 77,395,011
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 교차검증용 데이터셋 분할

# %%
# train, validation data 분할
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# %% [markdown]
# # 비디오 제너레이터를 이용해 학습

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (267, 20, 224, 224, 3)
# (267, 3)

# %%
plt.imshow(X_train[0][0])

# %%
plt.imshow(X_train[0][19])

# %%
classes = ['CricketShot', 'Punch', 'TennisSwing']

# %%
classes
# Out:
# ['CricketShot', 'Punch', 'TennisSwing']

# %%
# 이미지 사이즈
SIZE = (224, 224)
CHANNELS = 3

# %%
# 비디오 프레임의 이미지를 변형 할 객체 변형할 객체
train_image_data_gen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=30, # 이미지 회전 각도 최대 30도
	zoom_range=0.15, # 이미지 확대 비율 
	width_shift_range=0.2, # 이미지 가로 이동 비율
	height_shift_range=0.2, # 이미지 세로 이동 비율
	shear_range=0.15, # 이미지 기울기 비율
	horizontal_flip=True,# 이미지 좌우 반전을 가능하도록 설정
	fill_mode="nearest", # 이미지를 회전 이동시 빈공간을 채우는 방식
)

# %%
# 데이터 경로
data_path = "/content/drive/MyDrive/cloud_ai/16.모듈프로젝트04/workspace/"

# %%
# 비디오 파일의 클래스 v_다음이 클래스임
glob_pattern = data_path + 'train/v_{classname}_*.avi'

# %%
# 비디오 프레임 20개 생성할 객체
train_video_generator = VideoFrameGenerator(
    classes=classes, # 분류할 클래스 설정 : ['CricketShot', 'Punch', 'TennisSwing']
    glob_pattern=glob_pattern, # 파일명에서 클래스 정보를 따옴
    nb_frames=20,              # 시퀀스의 프레임의 수 
    split=.33,                 # 검증용 파일로 나눌 분할 비율 
    shuffle=True,              # 섞을 것 인지 
    batch_size=2,              # 배치사이즈는 2로 설정 한 배치의 시퀀스 수
    target_shape=SIZE,         # 요소 2에서 만든 (224,224)
    nb_channel=CHANNELS,       # 요소 2에서 만든 3  3이니까 RGB 채널 
    transformation=train_image_data_gen, # 요소 3에서 만든 비디오 프레임의 변형 
    use_frame_cache=True       # 프레임 캐시를 사용할지 여부 / 사용을 위해 다량의 메모리 필요 
    )
# Out:
# Total data: 3 classes for 356 files for train

# %%
glob_pattern
# Out:
# '/content/drive/MyDrive/cloud_ai/16.모듈프로젝트04/workspace/train/v_{classname}_*.avi'

# %%
# 비디오 프레임 샘플 데이터 조회 (배치사이즈 만큼)
keras_video.utils.show_sample(train_video_generator)

# %%
model.compile(
                  loss="categorical_crossentropy", 
                   optimizer=Adam(lr=1e-4),
                   metrics=["acc"]
              )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# # checkpoint 활용

# %%
# checkpoint 만들기
checkpoint_path = '/content/drive/MyDrive/check/tmp_checkpoint.ckpt'

checkpoint = ModelCheckpoint(
    filepath=checkpoint_path
    ,save_weights_only=True
    ,save_best_only=True
    ,monitor='val_loss'
    ,verbose=1
)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.fit(
	train_video_generator
	,batch_size = 10
	,epochs = 50
	,validation_data=(X_val, y_val)
	,callbacks=[checkpoint]
	,verbose=1
	)
# Out:
# Epoch 1/60
# 178/178 [==============================] - 94s 440ms/step - loss: 1.1036 - acc: 0.4691 - val_loss: 0.8197 - val_acc: 0.7528
#
# Epoch 00001: val_loss improved from inf to 0.81974, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 2/60
# 178/178 [==============================] - 70s 394ms/step - loss: 0.8483 - acc: 0.6264 - val_loss: 0.4836 - val_acc: 0.8989
#
# Epoch 00002: val_loss improved from 0.81974 to 0.48358, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 3/60
# 178/178 [==============================] - 70s 395ms/step - loss: 0.6915 - acc: 0.7247 - val_loss: 0.3263 - val_acc: 0.8539
#
# Epoch 00003: val_loss improved from 0.48358 to 0.32626, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 4/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.4836 - acc: 0.7949 - val_loss: 0.2206 - val_acc: 0.9101
#
# Epoch 00004: val_loss improved from 0.32626 to 0.22060, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 5/60
# 178/178 [==============================] - 70s 395ms/step - loss: 0.4281 - acc: 0.8230 - val_loss: 0.1739 - val_acc: 0.9551
#
# Epoch 00005: val_loss improved from 0.22060 to 0.17394, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 6/60
# 178/178 [==============================] - 71s 398ms/step - loss: 0.3480 - acc: 0.8511 - val_loss: 0.3541 - val_acc: 0.8876
#
# Epoch 00006: val_loss did not improve from 0.17394
# Epoch 7/60
# 178/178 [==============================] - 69s 388ms/step - loss: 0.3457 - acc: 0.8848 - val_loss: 0.2153 - val_acc: 0.8876
#
# Epoch 00007: val_loss did not improve from 0.17394
# Epoch 8/60
# 178/178 [==============================] - 69s 387ms/step - loss: 0.3464 - acc: 0.8680 - val_loss: 0.2341 - val_acc: 0.9101
#
# Epoch 00008: val_loss did not improve from 0.17394
# Epoch 9/60
# 178/178 [==============================] - 69s 389ms/step - loss: 0.3713 - acc: 0.8596 - val_loss: 0.2001 - val_acc: 0.8652
#
# Epoch 00009: val_loss did not improve from 0.17394
# Epoch 10/60
# 178/178 [==============================] - 69s 388ms/step - loss: 0.2344 - acc: 0.8989 - val_loss: 0.3093 - val_acc: 0.8539
#
# Epoch 00010: val_loss did not improve from 0.17394
# Epoch 11/60
# 178/178 [==============================] - 69s 388ms/step - loss: 0.2400 - acc: 0.9185 - val_loss: 0.1017 - val_acc: 0.9438
#
# Epoch 00011: val_loss improved from 0.17394 to 0.10172, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 12/60
# 178/178 [==============================] - 71s 398ms/step - loss: 0.3000 - acc: 0.8820 - val_loss: 0.1014 - val_acc: 0.9551
#
# Epoch 00012: val_loss improved from 0.10172 to 0.10144, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 13/60
# 178/178 [==============================] - 71s 399ms/step - loss: 0.1800 - acc: 0.9157 - val_loss: 0.0821 - val_acc: 0.9663
#
# Epoch 00013: val_loss improved from 0.10144 to 0.08209, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 14/60
# 178/178 [==============================] - 71s 396ms/step - loss: 0.1751 - acc: 0.9298 - val_loss: 0.0445 - val_acc: 0.9775
#
# Epoch 00014: val_loss improved from 0.08209 to 0.04449, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 15/60
# 178/178 [==============================] - 71s 398ms/step - loss: 0.2450 - acc: 0.9298 - val_loss: 0.1591 - val_acc: 0.9326
#
# Epoch 00015: val_loss did not improve from 0.04449
# Epoch 16/60
# 178/178 [==============================] - 69s 388ms/step - loss: 0.2128 - acc: 0.9129 - val_loss: 0.0837 - val_acc: 0.9663
#
# Epoch 00016: val_loss did not improve from 0.04449
# Epoch 17/60
# 178/178 [==============================] - 70s 390ms/step - loss: 0.1917 - acc: 0.9270 - val_loss: 0.1362 - val_acc: 0.9551
#
# Epoch 00017: val_loss did not improve from 0.04449
# Epoch 18/60
# 178/178 [==============================] - 69s 388ms/step - loss: 0.2829 - acc: 0.9045 - val_loss: 0.0819 - val_acc: 0.9775
#
# Epoch 00018: val_loss did not improve from 0.04449
# Epoch 19/60
# 178/178 [==============================] - 69s 389ms/step - loss: 0.1242 - acc: 0.9607 - val_loss: 0.0814 - val_acc: 0.9663
#
# Epoch 00019: val_loss did not improve from 0.04449
# Epoch 20/60
# 178/178 [==============================] - 69s 390ms/step - loss: 0.1462 - acc: 0.9494 - val_loss: 0.0700 - val_acc: 0.9551
#
# Epoch 00020: val_loss did not improve from 0.04449
# Epoch 21/60
# 178/178 [==============================] - 69s 390ms/step - loss: 0.3593 - acc: 0.8848 - val_loss: 0.1545 - val_acc: 0.9213
#
# Epoch 00021: val_loss did not improve from 0.04449
# Epoch 22/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.1602 - acc: 0.9242 - val_loss: 0.0432 - val_acc: 0.9775
#
# Epoch 00022: val_loss improved from 0.04449 to 0.04324, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 23/60
# 178/178 [==============================] - 71s 401ms/step - loss: 0.1119 - acc: 0.9607 - val_loss: 0.0336 - val_acc: 1.0000
#
# Epoch 00023: val_loss improved from 0.04324 to 0.03358, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 24/60
# 178/178 [==============================] - 71s 399ms/step - loss: 0.1393 - acc: 0.9522 - val_loss: 0.0388 - val_acc: 0.9888
#
# Epoch 00024: val_loss did not improve from 0.03358
# Epoch 25/60
# 178/178 [==============================] - 69s 389ms/step - loss: 0.0961 - acc: 0.9607 - val_loss: 0.0344 - val_acc: 0.9888
#
# Epoch 00025: val_loss did not improve from 0.03358
# Epoch 26/60
# 178/178 [==============================] - 69s 390ms/step - loss: 0.1197 - acc: 0.9691 - val_loss: 0.0662 - val_acc: 0.9775
#
# Epoch 00026: val_loss did not improve from 0.03358
# Epoch 27/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.0961 - acc: 0.9579 - val_loss: 0.0201 - val_acc: 1.0000
#
# Epoch 00027: val_loss improved from 0.03358 to 0.02009, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 28/60
# 178/178 [==============================] - 72s 405ms/step - loss: 0.2620 - acc: 0.9326 - val_loss: 0.0221 - val_acc: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.02009
# Epoch 29/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.1351 - acc: 0.9494 - val_loss: 0.0391 - val_acc: 0.9775
#
# Epoch 00029: val_loss did not improve from 0.02009
# Epoch 30/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.1201 - acc: 0.9635 - val_loss: 0.0266 - val_acc: 1.0000
#
# Epoch 00030: val_loss did not improve from 0.02009
# Epoch 31/60
# 178/178 [==============================] - 69s 389ms/step - loss: 0.0658 - acc: 0.9747 - val_loss: 0.2321 - val_acc: 0.9438
#
# Epoch 00031: val_loss did not improve from 0.02009
# Epoch 32/60
# 178/178 [==============================] - 69s 388ms/step - loss: 0.0686 - acc: 0.9831 - val_loss: 0.1000 - val_acc: 0.9775
#
# Epoch 00032: val_loss did not improve from 0.02009
# Epoch 33/60
# 178/178 [==============================] - 69s 390ms/step - loss: 0.1260 - acc: 0.9607 - val_loss: 0.3998 - val_acc: 0.8876
#
# Epoch 00033: val_loss did not improve from 0.02009
# Epoch 34/60
# 178/178 [==============================] - 69s 389ms/step - loss: 0.1310 - acc: 0.9691 - val_loss: 0.0279 - val_acc: 0.9888
#
# Epoch 00034: val_loss did not improve from 0.02009
# Epoch 35/60
# 178/178 [==============================] - 69s 390ms/step - loss: 0.0932 - acc: 0.9691 - val_loss: 0.0146 - val_acc: 1.0000
#
# Epoch 00035: val_loss improved from 0.02009 to 0.01465, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 36/60
# 178/178 [==============================] - 71s 398ms/step - loss: 0.1350 - acc: 0.9522 - val_loss: 0.0252 - val_acc: 0.9775
#
# Epoch 00036: val_loss did not improve from 0.01465
# Epoch 37/60
# 178/178 [==============================] - 70s 392ms/step - loss: 0.0687 - acc: 0.9831 - val_loss: 0.0227 - val_acc: 0.9888
#
# Epoch 00037: val_loss did not improve from 0.01465
# Epoch 38/60
# 178/178 [==============================] - 69s 389ms/step - loss: 0.0518 - acc: 0.9888 - val_loss: 0.0146 - val_acc: 1.0000
#
# Epoch 00038: val_loss improved from 0.01465 to 0.01455, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 39/60
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0342 - acc: 0.9916 - val_loss: 0.0025 - val_acc: 1.0000
#
# Epoch 00039: val_loss improved from 0.01455 to 0.00253, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 40/60
# 178/178 [==============================] - 71s 401ms/step - loss: 0.0631 - acc: 0.9831 - val_loss: 9.2404e-04 - val_acc: 1.0000
#
# Epoch 00040: val_loss improved from 0.00253 to 0.00092, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 41/60
# 178/178 [==============================] - 71s 401ms/step - loss: 0.0476 - acc: 0.9803 - val_loss: 0.0064 - val_acc: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.00092
# Epoch 42/60
# 178/178 [==============================] - 69s 390ms/step - loss: 0.0146 - acc: 1.0000 - val_loss: 5.0068e-04 - val_acc: 1.0000
#
# Epoch 00042: val_loss improved from 0.00092 to 0.00050, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 43/60
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0083 - acc: 0.9972 - val_loss: 0.0013 - val_acc: 1.0000
#
# Epoch 00043: val_loss did not improve from 0.00050
# Epoch 44/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.1489 - acc: 0.9579 - val_loss: 0.0025 - val_acc: 1.0000
#
# Epoch 00044: val_loss did not improve from 0.00050
# Epoch 45/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.0172 - acc: 1.0000 - val_loss: 0.0015 - val_acc: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.00050
# Epoch 46/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.1035 - acc: 0.9803 - val_loss: 0.0016 - val_acc: 1.0000
#
# Epoch 00046: val_loss did not improve from 0.00050
# Epoch 47/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.1855 - acc: 0.9579 - val_loss: 0.0041 - val_acc: 1.0000
#
# Epoch 00047: val_loss did not improve from 0.00050
# Epoch 48/60
# 178/178 [==============================] - 70s 390ms/step - loss: 0.0163 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
#
# Epoch 00048: val_loss did not improve from 0.00050
# Epoch 49/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.0289 - acc: 0.9831 - val_loss: 0.0116 - val_acc: 0.9888
#
# Epoch 00049: val_loss did not improve from 0.00050
# Epoch 50/60
# 178/178 [==============================] - 70s 392ms/step - loss: 0.0403 - acc: 0.9860 - val_loss: 5.8100e-04 - val_acc: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.00050
# Epoch 51/60
# 178/178 [==============================] - 70s 391ms/step - loss: 0.1925 - acc: 0.9494 - val_loss: 0.0017 - val_acc: 1.0000
#
# Epoch 00051: val_loss did not improve from 0.00050
# Epoch 52/60
# 178/178 [==============================] - 70s 392ms/step - loss: 0.0283 - acc: 0.9916 - val_loss: 0.0019 - val_acc: 1.0000
#
# Epoch 00052: val_loss did not improve from 0.00050
# Epoch 53/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.0933 - acc: 0.9775 - val_loss: 0.0060 - val_acc: 1.0000
#
# Epoch 00053: val_loss did not improve from 0.00050
# Epoch 54/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.0557 - acc: 0.9888 - val_loss: 0.0327 - val_acc: 0.9888
#
# Epoch 00054: val_loss did not improve from 0.00050
# Epoch 55/60
# 178/178 [==============================] - 70s 392ms/step - loss: 0.0596 - acc: 0.9860 - val_loss: 0.0063 - val_acc: 1.0000
#
# Epoch 00055: val_loss did not improve from 0.00050
# Epoch 56/60
# 178/178 [==============================] - 70s 393ms/step - loss: 0.0201 - acc: 0.9944 - val_loss: 6.9008e-04 - val_acc: 1.0000
#
# Epoch 00056: val_loss did not improve from 0.00050
# Epoch 57/60
# 178/178 [==============================] - 70s 392ms/step - loss: 0.0319 - acc: 0.9916 - val_loss: 0.0054 - val_acc: 1.0000
#
# Epoch 00057: val_loss did not improve from 0.00050
# Epoch 58/60
# 178/178 [==============================] - 70s 392ms/step - loss: 0.1502 - acc: 0.9579 - val_loss: 0.0171 - val_acc: 0.9888
#
# Epoch 00058: val_loss did not improve from 0.00050
# Epoch 59/60
# 178/178 [==============================] - 70s 390ms/step - loss: 0.0739 - acc: 0.9803 - val_loss: 4.7110e-04 - val_acc: 1.0000
#
# Epoch 00059: val_loss improved from 0.00050 to 0.00047, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 60/60
# 178/178 [==============================] - 71s 401ms/step - loss: 0.0311 - acc: 0.9860 - val_loss: 1.1976e-04 - val_acc: 1.0000
#
# Epoch 00060: val_loss improved from 0.00047 to 0.00012, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt

# %%
model.load_weights(checkpoint_path)

# %%
# 모델 저장
model.save("/content/drive/MyDrive/model/cnn_gru.h5")

# %% [markdown]
# # test

# %%
X_test = np.load('/content/drive/MyDrive/data/X_test_wide(5).npy')
y_test = np.load('/content/drive/MyDrive/data/y_test_wide(5).npy')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 이미지 테스트
model.evaluate(
    X_test, y_test
    , batch_size = 8 # epochs=50
    # 
)
# Out:
# 18/18 [==============================] - 2s 74ms/step - loss: 1.3163 - acc: 0.7737
# [1.3163363933563232, 0.7737226486206055]
