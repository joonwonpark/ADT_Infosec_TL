# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
! git clone https://github.com/metal3d/keras-video-generators.git
# Out:
# Cloning into 'keras-video-generators'...
# remote: Enumerating objects: 614, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 614 (delta 47), reused 75 (delta 35), pack-reused 514
# Receiving objects: 100% (614/614), 7.77 MiB | 12.62 MiB/s, done.
# Resolving deltas: 100% (279/279), done.

# %%
# 다운로드한 폴더로 이동
import os
os.chdir("/content/keras-video-generators/")

# %%
# git 컴파일
! python setup.py build
# Out:
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'licence_file'
#   warnings.warn(msg)
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/keras_video
# copying src/keras_video/__init__.py -> build/lib/keras_video
# copying src/keras_video/generator.py -> build/lib/keras_video
# copying src/keras_video/sliding.py -> build/lib/keras_video
# copying src/keras_video/utils.py -> build/lib/keras_video
# copying src/keras_video/flow.py -> build/lib/keras_video

# %%
# 폴더 생성
! mkdir /content/keras_video
# git 파일 복사 /content/keras_video
! cp /content/keras-video-generators/build/lib/keras_video/*.*  /content/keras_video

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np

import cv2
import pandas as pd
from tensorflow.keras.utils import to_categorical
from keras_video import VideoFrameGenerator

import sklearn
import keras_video.utils
from tensorflow_docs.vis import embed
import imageio
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from sklearn.model_selection import train_test_split

from keras.applications import mobilenet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, TimeDistributed, GRU
from keras.layers import Dropout
from tensorflow.keras.optimizers import Adam

# %%
data_path = '/content/drive/MyDrive'

# %%
X_train = np.load(data_path + '/data/X_train_wide(5).npy')

# %%
y_train = np.load(data_path + '/data/y_train_wide(5).npy')

# %%
X_train.shape
# Out:
# (356, 20, 224, 224, 3)

# %%
#입력값을 읽어서 예측을 할 Sequential 객체 생성
model = Sequential()

# %%
model.add(
    TimeDistributed(
        tf.keras.applications.mobilenet.MobileNet(
            weights='imagenet'
            ,include_top=False
            ,input_shape=(224,224,3)
        )
        ,input_shape=(20,224,224,3)
    )
)
model.add(TimeDistributed(Dropout(0.5)))

model.add(TimeDistributed(Flatten()))
model.add(GRU(256, dropout=0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.8))
model.add(Dense(3, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#생성된 모델 정보 출력
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 20, 7, 7, 1024)    3228864
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 7, 7, 1024)    0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 20, 50176)         0
# _________________________________________________________________
# gru (GRU)                    (None, 256)               38733312
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 41,995,459
# Trainable params: 41,973,571
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# # 교차검증용 데이터셋 분할

# %%
# train, validation data 분할
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# %% [markdown]
# # 비디오 제너레이터를 이용해 학습

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (267, 20, 224, 224, 3)
# (267, 3)

# %%
plt.imshow(X_train[0][0])

# %%
plt.imshow(X_train[0][19])

# %%
classes = ['CricketShot', 'Punch', 'TennisSwing']

# %%
classes
# Out:
# ['CricketShot', 'Punch', 'TennisSwing']

# %%
# 이미지 사이즈
SIZE = (224, 224)
CHANNELS = 3

# %%
# 비디오 프레임의 이미지를 변형 할 객체 변형할 객체
train_image_data_gen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=30, # 이미지 회전 각도 최대 30도
	zoom_range=0.15, # 이미지 확대 비율 
	width_shift_range=0.2, # 이미지 가로 이동 비율
	height_shift_range=0.2, # 이미지 세로 이동 비율
	shear_range=0.15, # 이미지 기울기 비율
	horizontal_flip=True,# 이미지 좌우 반전을 가능하도록 설정
	fill_mode="nearest", # 이미지를 회전 이동시 빈공간을 채우는 방식
)

# %%
# 데이터 경로
data_path = "/content/drive/MyDrive/cloud_ai/16.모듈프로젝트04/workspace/"

# %%
# 비디오 파일의 클래스 v_다음이 클래스임
glob_pattern = data_path + 'train/v_{classname}_*.avi'

# %%
# 비디오 프레임 20개 생성할 객체
train_video_generator = VideoFrameGenerator(
    classes=classes, # 분류할 클래스 설정 : ['CricketShot', 'Punch', 'TennisSwing']
    glob_pattern=glob_pattern, # 파일명에서 클래스 정보를 따옴
    nb_frames=20,              # 시퀀스의 프레임의 수 
    split=.33,                 # 검증용 파일로 나눌 분할 비율 
    shuffle=True,              # 섞을 것 인지 
    batch_size=2,              # 배치사이즈는 2로 설정 한 배치의 시퀀스 수
    target_shape=SIZE,         # 요소 2에서 만든 (224,224)
    nb_channel=CHANNELS,       # 요소 2에서 만든 3  3이니까 RGB 채널 
    transformation=train_image_data_gen, # 요소 3에서 만든 비디오 프레임의 변형 
    use_frame_cache=True       # 프레임 캐시를 사용할지 여부 / 사용을 위해 다량의 메모리 필요 
    )
# Out:
# Total data: 3 classes for 356 files for train

# %%
glob_pattern
# Out:
# '/content/drive/MyDrive/cloud_ai/16.모듈프로젝트04/workspace/train/v_{classname}_*.avi'

# %%
# 비디오 프레임 샘플 데이터 조회 (배치사이즈 만큼)
keras_video.utils.show_sample(train_video_generator)

# %%
model.compile(
                  loss="categorical_crossentropy", 
                   optimizer=Adam(lr=1e-4),
                   metrics=["acc"]
              )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# # checkpoint 활용

# %%
# checkpoint 만들기
checkpoint_path = '/content/drive/MyDrive/check/tmp_checkpoint.ckpt'

checkpoint = ModelCheckpoint(
    filepath=checkpoint_path
    ,save_weights_only=True
    ,save_best_only=True
    ,monitor='val_loss'
    ,verbose=1
)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.fit(
	train_video_generator
	,batch_size = 3
	,epochs = 80
	,validation_data=(X_val, y_val)
	,callbacks=[checkpoint]
	,verbose=1
	)
# Out:
# Epoch 1/80
# 178/178 [==============================] - 400s 2s/step - loss: 1.5758 - acc: 0.3876 - val_loss: 0.9068 - val_acc: 0.6292
#
# Epoch 00001: val_loss improved from inf to 0.90685, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 2/80
# 178/178 [==============================] - 72s 403ms/step - loss: 1.1087 - acc: 0.4635 - val_loss: 0.7386 - val_acc: 0.8652
#
# Epoch 00002: val_loss improved from 0.90685 to 0.73863, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 3/80
# 178/178 [==============================] - 72s 405ms/step - loss: 1.0912 - acc: 0.4579 - val_loss: 0.6705 - val_acc: 0.7528
#
# Epoch 00003: val_loss improved from 0.73863 to 0.67049, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 4/80
# 178/178 [==============================] - 72s 403ms/step - loss: 0.9207 - acc: 0.5983 - val_loss: 0.4665 - val_acc: 0.9551
#
# Epoch 00004: val_loss improved from 0.67049 to 0.46649, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 5/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.8070 - acc: 0.6517 - val_loss: 0.4180 - val_acc: 0.9101
#
# Epoch 00005: val_loss improved from 0.46649 to 0.41803, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0773 - acc: 0.9803 - val_loss: 0.0192 - val_acc: 1.0000
#
# Epoch 00037: val_loss did not improve from 0.00496
# Epoch 38/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0655 - acc: 0.9860 - val_loss: 0.0094 - val_acc: 1.0000
#
# Epoch 00038: val_loss did not improve from 0.00496
# Epoch 39/80
# 178/178 [==============================] - 71s 397ms/step - loss: 0.0627 - acc: 0.9831 - val_loss: 9.3652e-04 - val_acc: 1.0000
#
# Epoch 00039: val_loss improved from 0.00496 to 0.00094, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 40/80
# 178/178 [==============================] - 72s 403ms/step - loss: 0.1010 - acc: 0.9691 - val_loss: 0.0221 - val_acc: 1.0000
#
# Epoch 00040: val_loss did not improve from 0.00094
# Epoch 41/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0982 - acc: 0.9803 - val_loss: 0.0025 - val_acc: 1.0000
#
# Epoch 00041: val_loss did not improve from 0.00094
# Epoch 42/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0501 - acc: 0.9888 - val_loss: 0.0661 - val_acc: 0.9551
#
# Epoch 00042: val_loss did not improve from 0.00094
# Epoch 43/80
# 178/178 [==============================] - 72s 402ms/step - loss: 0.0261 - acc: 0.9944 - val_loss: 0.0021 - val_acc: 1.0000
#
# Epoch 00043: val_loss did not improve from 0.00094
# Epoch 44/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0764 - acc: 0.9860 - val_loss: 0.0663 - val_acc: 0.9551
#
# Epoch 00044: val_loss did not improve from 0.00094
# Epoch 45/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0774 - acc: 0.9747 - val_loss: 0.1337 - val_acc: 0.9438
#
# Epoch 00045: val_loss did not improve from 0.00094
# Epoch 46/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0860 - acc: 0.9691 - val_loss: 0.0466 - val_acc: 0.9888
#
# Epoch 00046: val_loss did not improve from 0.00094
# Epoch 47/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0616 - acc: 0.9831 - val_loss: 0.0021 - val_acc: 1.0000
#
# Epoch 00047: val_loss did not improve from 0.00094
# Epoch 48/80
# 178/178 [==============================] - 71s 396ms/step - loss: 0.0253 - acc: 0.9944 - val_loss: 0.0363 - val_acc: 0.9775
#
# Epoch 00048: val_loss did not improve from 0.00094
# Epoch 49/80
# 178/178 [==============================] - 71s 396ms/step - loss: 0.0577 - acc: 0.9831 - val_loss: 0.0060 - val_acc: 1.0000
#
# Epoch 00049: val_loss did not improve from 0.00094
# Epoch 50/80
# 178/178 [==============================] - 71s 397ms/step - loss: 0.0730 - acc: 0.9803 - val_loss: 0.0183 - val_acc: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.00094
# Epoch 51/80
# 178/178 [==============================] - 71s 397ms/step - loss: 0.0929 - acc: 0.9579 - val_loss: 0.0025 - val_acc: 1.0000
#
# Epoch 00051: val_loss did not improve from 0.00094
# Epoch 52/80
# 178/178 [==============================] - 71s 396ms/step - loss: 0.0875 - acc: 0.9747 - val_loss: 0.0355 - val_acc: 0.9663
#
# Epoch 00052: val_loss did not improve from 0.00094
# Epoch 53/80
# 178/178 [==============================] - 71s 397ms/step - loss: 0.0402 - acc: 0.9888 - val_loss: 0.0161 - val_acc: 1.0000
#
# Epoch 00053: val_loss did not improve from 0.00094
# Epoch 54/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0605 - acc: 0.9831 - val_loss: 0.0368 - val_acc: 0.9663
#
# Epoch 00054: val_loss did not improve from 0.00094
# Epoch 55/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0673 - acc: 0.9831 - val_loss: 0.0156 - val_acc: 0.9888
#
# Epoch 00055: val_loss did not improve from 0.00094
# Epoch 56/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0250 - acc: 0.9916 - val_loss: 0.0538 - val_acc: 0.9551
#
# Epoch 00056: val_loss did not improve from 0.00094
# Epoch 57/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0324 - acc: 0.9916 - val_loss: 0.0229 - val_acc: 1.0000
#
# Epoch 00057: val_loss did not improve from 0.00094
# Epoch 58/80
# 178/178 [==============================] - 71s 397ms/step - loss: 0.0438 - acc: 0.9831 - val_loss: 0.0960 - val_acc: 0.9551
#
# Epoch 00058: val_loss did not improve from 0.00094
# Epoch 59/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0407 - acc: 0.9944 - val_loss: 0.0480 - val_acc: 0.9663
#
# Epoch 00059: val_loss did not improve from 0.00094
# Epoch 60/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.1424 - acc: 0.9607 - val_loss: 0.0286 - val_acc: 0.9888
#
# Epoch 00060: val_loss did not improve from 0.00094
# Epoch 61/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0205 - acc: 0.9972 - val_loss: 0.0178 - val_acc: 0.9888
#
# Epoch 00061: val_loss did not improve from 0.00094
# Epoch 62/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0737 - acc: 0.9860 - val_loss: 0.0097 - val_acc: 1.0000
#
# Epoch 00062: val_loss did not improve from 0.00094
# Epoch 63/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0935 - acc: 0.9663 - val_loss: 0.0122 - val_acc: 1.0000
#
# Epoch 00063: val_loss did not improve from 0.00094
# Epoch 64/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0831 - acc: 0.9831 - val_loss: 0.0298 - val_acc: 0.9888
#
# Epoch 00064: val_loss did not improve from 0.00094
# Epoch 65/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0641 - acc: 0.9747 - val_loss: 0.0165 - val_acc: 0.9888
#
# Epoch 00065: val_loss did not improve from 0.00094
# Epoch 66/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0285 - acc: 0.9916 - val_loss: 0.0311 - val_acc: 1.0000
#
# Epoch 00066: val_loss did not improve from 0.00094
# Epoch 67/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0342 - acc: 0.9831 - val_loss: 0.1378 - val_acc: 0.9551
#
# Epoch 00067: val_loss did not improve from 0.00094
# Epoch 68/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0282 - acc: 0.9888 - val_loss: 0.0799 - val_acc: 0.9551
#
# Epoch 00068: val_loss did not improve from 0.00094
# Epoch 69/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0125 - acc: 0.9944 - val_loss: 0.1723 - val_acc: 0.9551
#
# Epoch 00069: val_loss did not improve from 0.00094
# Epoch 70/80
# 178/178 [==============================] - 71s 398ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 0.1601 - val_acc: 0.9551
#
# Epoch 00070: val_loss did not improve from 0.00094
# Epoch 71/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0075 - acc: 1.0000 - val_loss: 0.1795 - val_acc: 0.9551
#
# Epoch 00071: val_loss did not improve from 0.00094
# Epoch 72/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.1671 - val_acc: 0.9551
#
# Epoch 00072: val_loss did not improve from 0.00094
# Epoch 73/80
# 178/178 [==============================] - 72s 401ms/step - loss: 0.0099 - acc: 0.9972 - val_loss: 0.1065 - val_acc: 0.9551
#
# Epoch 00073: val_loss did not improve from 0.00094
# Epoch 74/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0966 - acc: 0.9831 - val_loss: 0.0058 - val_acc: 1.0000
#
# Epoch 00074: val_loss did not improve from 0.00094
# Epoch 75/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.1192 - acc: 0.9579 - val_loss: 0.0293 - val_acc: 0.9888
#
# Epoch 00075: val_loss did not improve from 0.00094
# Epoch 76/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0582 - acc: 0.9860 - val_loss: 0.0253 - val_acc: 0.9888
#
# Epoch 00076: val_loss did not improve from 0.00094
# Epoch 77/80
# 178/178 [==============================] - 71s 399ms/step - loss: 0.0243 - acc: 0.9972 - val_loss: 7.0896e-04 - val_acc: 1.0000
#
# Epoch 00077: val_loss improved from 0.00094 to 0.00071, saving model to /content/drive/MyDrive/check/tmp_checkpoint.ckpt
# Epoch 78/80
# 178/178 [==============================] - 72s 403ms/step - loss: 0.0097 - acc: 0.9972 - val_loss: 7.5074e-04 - val_acc: 1.0000
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/80
# 178/178 [==============================] - 72s 402ms/step - loss: 0.0558 - acc: 0.9888 - val_loss: 0.0361 - val_acc: 0.9888
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/80
# 178/178 [==============================] - 71s 400ms/step - loss: 0.0459 - acc: 0.9888 - val_loss: 0.0014 - val_acc: 1.0000
#
# Epoch 00080: val_loss did not improve from 0.00071

# %%
model.load_weights(checkpoint_path)

# %%
# 모델 저장
model.save("/content/drive/MyDrive/model/MobileNet+GRU.h5")

# %% [markdown]
# # test

# %%
X_test = np.load('/content/drive/MyDrive/data/X_test_wide(5).npy')
y_test = np.load('/content/drive/MyDrive/data/y_test_wide(5).npy')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 이미지 테스트
model.evaluate(
    X_test, y_test
    , batch_size = 8 # epochs=80
    # loss: 0.0243 - acc: 0.9972 - val_loss: 7.0896e-04 - val_acc: 1.0000
)
# Out:
# 18/18 [==============================] - 3s 122ms/step - loss: 0.3506 - acc: 0.9124
# [0.35062822699546814, 0.9124087691307068]
